# %%
import pandas as pd
import os

for index in range(1,203093):
    os.mkdir("../validation/"+str(index))

# %%
df = pd.read_csv("../GoogleRetrievalLandmark2020/train.csv")
df = df.sort_values(by = "id")
df = df.reset_index(drop = True)
df
# Out:
#                        id  landmark_id
# 0        0000059611c7d079       107382
# 1        000014b1f770f640        15430
# 2        000015f76534add3       158262
# 3        00001ae42cd00356       172552
# 4        00001b2ba2c69ac5        91402
# ...                   ...          ...
# 1580465  ffffa7978e8cf3c0        77172
# 1580466  ffffa7a97e805849        94741
# 1580467  ffffbcd15dc0dc7d        52799
# 1580468  ffffd21941691bea       180477
# 1580469  fffffaad1727f1c1       197573
#
# [1580470 rows x 2 columns]

# %%
import shutil

for index in range(1300001,1580470):
    if (index % 100 == 0):
        print(index)
    img_name = df['id'][index]
    image_path = "../GoogleRetrievalLandmark2020/train/" + str(img_name)[0] + "/" + str(img_name)[1] + "/" + str(img_name)[2] + "/" + str(img_name) + ".jpg"
    shutil.copy(image_path, "../validation/" + str(df['landmark_id'][index]))
# Out:
# 1300100
# 1300200
# 1300300
# 1300400
# 1300500
# 1300600
# 1300700
# 1300800
# 1300900
# 1301000
# 1301100
# 1301200
# 1301300
# 1301400
# 1301500
# 1301600
# 1301700
# 1301800
# 1301900
# 1302000
# 1302100
# 1302200
# 1302300
# 1302400
# 1302500
# 1302600
# 1302700
# 1302800
# 1302900
# 1303000
# 1303100
# 1303200
# 1303300
# 1303400
# 1303500
# 1303600
# 1303700
# 1303800
# 1303900
# 1304000
# 1304100
# 1304200
# 1304300
# 1304400
# 1304500
# 1304600
# 1304700
# 1304800
# 1304900
# 1305000
# 1305100
# 1305200
# 1305300
# 1305400
# 1305500
# 1305600
# 1305700
# 1305800
# 1305900
# 1306000
# 1306100
# 1306200
# 1306300
# 1306400
# 1306500
# 1306600
# 1306700
# 1306800
# 1306900
# 1307000
# 1307100
# 1307200
# 1307300
# 1307400
# 1307500
# 1307600
# 1307700
# 1307800
# 1307900
# 1308000
# 1308100
# 1308200
# 1308300
# 1308400
# 1308500
# 1308600
# 1308700
# 1308800
# 1308900
# 1309000
# 1309100
# 1309200
# 1309300
# 1309400
# 1309500
# 1309600
# 1309700
# 1309800
# 1309900
# 1310000
# ...

# %%
for index in range(1300000,1580470):
    if (index % 100 == 0):
        print(index)
    img_name = df['id'][index]
    image_path = "../GoogleRetrievalLandmark2020/validationimport pandas as pd
import os



for index in range(1,203093):
    os.mkdir("../train/"+str(index))

df = pd.read_csv("../GoogleRetrievalLandmark2020/train.csv")
df = df.sort_values(by = "id")
df = df.reset_index(drop = True)
df

import shutil

for index in range(1,1300000):
    if (index % 100 == 0):
        print(index)
    img_name = df['id'][index]
    image_path = "../GoogleRetrievalLandmark2020/train/" + str(img_name)[0] + "/" + str(img_name)[1] + "/" + str(img_name)[2] + "/" + str(img_name) + ".jpg"
    shutil.copy(image_path, "../train/" + str(df['landmark_id'][index]))

/" + str(img_name)[0] + "/" + str(img_name)[1] + "/" + str(img_name)[2] + "/" + str(img_name) + ".jpg"
    shutil.copy(image_path, "../train/" + str(df['landmark_id'][index]))
